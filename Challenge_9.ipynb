# %% [markdown]
# # Antes de empezar :
#    - Estos ejercicios están relacionados con las lecciones Subconjunto y Estadísticas descriptivas.
#    - Tenga en cuenta que necesitará utilizar algunas de las funciones que aprendió en las lecciones anteriores.
#    - Todos los conjuntos de datos se proporcionan en la carpeta `your-code` de este laboratorio.
#    - Elabora tus códigos y resultados tanto como puedas.
#    - Esfuérzate al máximo para responder a las preguntas y completar las tareas y, sobre todo, ¡¡¡disfruta del proceso!!!

# %% [markdown]
# #### Importa todas las librerías necesarias

# %%
# import libraries here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

orders = pd.read_csv('./datasets/Orders.csv')
temp_states = pd.read_csv('./datasets/Temp_States.csv')
employee = pd.read_csv('./datasets/Employee.csv')

# %% [markdown]
# # Desafío 1

# %% [markdown]
# #### En este reto utilizaremos el archivo `Temp_States.csv`.
#
# #### Primero impórtalo en un marco de datos llamado `temp`.

# %%
# YOUR CODE HERE
temp = pd.read_csv('./datasets/Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore los tipos de datos del marco de datos Temp. ¿Qué tipo de datos tenemos? Comenta tu resultado.

# %%
print(temp.columns)
# Out:
# Index(['City', 'State', 'Temperature'], dtype='object')

# %%
# YOUR CODE HERE
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %% [markdown]
# Tipos de datos de las columnas:
#
# > City -> object / string
#
# > State -> object / string
#
# > Temperature -> float

# %% [markdown]
# #### Selecciona las filas en las que el estado es New York

# %%
# YOUR CODE HERE
temp_ny = temp[temp['State'] == 'New York']
temp_ny.head()
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### ¿Cuál es la temperatura media de las ciudades de Nueva York?

# %%
# YOUR CODE HERE
mean_temp_ny = temp_ny['Temperature'].mean()
print('La temperatura media de las ciudades de Nueva York es de :', mean_temp_ny, 'grados centigrados.')
# Out:
# La temperatura media de las ciudades de Nueva York es de : 10.74074074074074 grados centigrados.

# %% [markdown]
# #### Queremos conocer las ciudades y estados con temperaturas superiores a 15 grados centígrados.

# %%
# your answer here
temp_15 = temp[temp['Temperature'] > 15]
temp_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Ahora, devuelva sólo las ciudades que tengan una temperatura superior a 15 grados centígrados.

# %%
# YOUR CODE HERE
cities_temp_15 = temp_15[['City', 'Temperature']]
cities_temp_15
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Queremos saber qué ciudades tienen una temperatura superior a 15 grados Celcius e inferior a 20 grados Celcius
#
# *Pista: Primero escriba la condición y luego seleccione las filas.

# %%
# YOUR CODE HERE
temp_15[temp_15['Temperature'] < 20][['City', 'Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %%
temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Halla la media y la desviación estándar de la temperatura de cada estado.
#
# *Pista: Utiliza las funciones de la lección Manipulación de datos*.

# %%
# YOUR CODE HERE
temp.groupby('State')['Temperature'].agg(['mean', 'std'])
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # Desafío 2

# %% [markdown]
# #### Cargar el fichero `employee.csv` en un DataFrame. Llama al dataframe `employee`.

# %%
# YOUR CODE HERE
employee = pd.read_csv('./datasets/Employee.csv')

# %% [markdown]
# #### Explore los tipos de datos del marco de datos Temp. Comenta tus resultados

# %%
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# Tipos de datos de las columnas:
#
# > Name -> object / string
#
# > Department -> object / string
#
# > Education -> object / string
#
# > Gender -> object / string
#
# > Title -> object / string
#
# > Years -> int
#
# > Salary -> int

# %% [markdown]
# #### Muestre visualmente la distribución de frecuencias (histograma) del conjunto de datos de empleados. Describa en pocas palabras estos histogramas.

# %%
# your answer here
sns.histplot(employee['Salary'])
plt.title('Employee Salary Histogram')
# Out:
# Text(0.5, 1.0, 'Employee Salary Histogram')

# %% [markdown]
# En el histograma de salarios, se observa que la mayor parte de los ingresos se agrupan entre 30 y 35, con un total de 4 personas en ese rango. La siguiente categoría más frecuente corresponde a 3 personas que ganan entre 55 y 60, y por último, hay 2 personas en el rango de 65 a 70. Esto sugiere que la mayoría de las personas tienen ingresos relativamente bajos.

# %%
# YOUR CODE HERE
sns.histplot(employee['Years'], color='darkorange')
plt.title('Employee Years Histogram')
# Out:
# Text(0.5, 1.0, 'Employee Years Histogram')

# %%
employee.nlargest(2,'Years')
# Out:
#      Name Department Education Gender Title  Years  Salary
# 6  Carlos         IT    Master      M    VP      8      70
# 8     Ana         HR    Master      F    VP      8      70

# %% [markdown]
# La mayor parte de los empleados tiene poca antigüedad en la empresa, con un tiempo de servicio entre 1 y 2 años. Hay algunos casos de trabajadores que han estado entre 3 y 5 años, y se observa que entre 7 y 8 años hay 3 casos. Notamos que los empleados con 8 años de antigüedad ocupan posiciones de liderazgo como "VP" (según lo indicado en la tabla) y son los que tienen los salarios más altos.

# %% [markdown]
# #### ¿Cuál es el salario medio en esta empresa?

# %%
# YOUR CODE HERE
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### ¿Cuál es el salario más alto?

# %%
# YOUR CODE HERE
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### ¿Cuál es el salario más bajo?

# %%
# YOUR CODE HERE
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### ¿Quiénes son los empleados con el salario más bajo?

# %%
# YOUR CODE HERE
employee.nsmallest(4, 'Salary')
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 3  Sonia         HR  Bachelor      F  analyst      4      35

# %% [markdown]
# #### ¿Podría darnos toda la información sobre un empleado llamado David?

# %%
# YOUR CODE HERE
employee[employee['Name'] == "David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Podría dar sólo el sueldo de David?

# %%
# YOUR CODE HERE
employee[employee['Name'] == "David"]['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Printea todas las líneas en las que el cargo es asociado

# %%
# YOUR CODE HERE
employee[employee['Title'] == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Printea las 3 primeras filas de tu dataframe
#
# ##### Consejo : Hay 2 maneras de hacerlo. Hazlo de las dos maneras

# %%
# YOUR CODE HERE
employee.head(2)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30

# %%
# YOUR CODE HERE
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Encuentra a los empleados cuyo cargo es asociado y cuyo salario es superior a 55?

# %%
# YOUR CODE HERE
employee[(employee['Title'] == "associate") & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Agrupa a los empleados en función del número de años que llevan trabajando. ¿Cuáles son los salarios medios de cada grupo?

# %%
# YOUR CODE HERE
employee.groupby('Years').mean('Salary')
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# #### ¿Cuál es el salario medio por título?

# %%
# YOUR CODE HERE
employee.groupby('Title').mean('Salary')
# Out:
#            Years     Salary
# Title
# VP          8.00  70.000000
# analyst     2.25  32.500000
# associate   4.00  56.666667

# %% [markdown]
# #### Muestra un resumen visual de los datos utilizando boxplot. ¿Cuáles son los cuartiles primero y tercero? Comenta tus resultados.
#
# * Pista : Cuantiles vs Cuartiles*.
# En Probabilidad y Estadística, los cuantiles son puntos de corte que dividen el rango de una distribución de probabilidad en intervalos continuos con probabilidades iguales. Cuando la división es en cuatro partes, los valores de la variable correspondientes al 25%, 50% y 75% de la distribución total se denominan cuartiles.

# %%
# YOUR CODE HERE
sns.boxplot(employee, orient='h')
plt.title("Employee Box Plot")
# Out:
# Text(0.5, 1.0, 'Employee Box Plot')

# %%
# print first quartile here
sns.boxplot(employee['Salary'], orient='h')
plt.title("Salary Years Box Plot")
# Out:
# Text(0.5, 1.0, 'Salary Years Box Plot')

# %%
# print third quartile here
sns.boxplot(employee['Years'], orient='h', color='darkorange')
plt.title("Employee Years Box Plot")
# Out:
# Text(0.5, 1.0, 'Employee Years Box Plot')

# %%
employee[['Years']].quantile([0.25, 0.5, 0.75])  # Q1, median, Q3
# Out:
#       Years
# 0.25    2.0
# 0.50    3.0
# 0.75    7.0

# %%
employee[['Salary']].quantile([0.25, 0.5, 0.75])  # Q1, median, Q3
# Out:
#       Salary
# 0.25    35.0
# 0.50    55.0
# 0.75    60.0

# %% [markdown]
# #### ¿Es diferente el salario medio por género?

# %%
# your answer here
employee.groupby('Gender').mean('Salary')
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %% [markdown]
# #### Encuentra el mínimo, la media y el máximo de todas las columnas numéricas para cada Departamento.
#
# ##### Sugerencia: Utiliza las funciones de la lección Manipulación de Datos

# %%
# your answer here
employee.groupby('Department').agg({
    'Years': ['min', 'mean', 'max'],
    'Salary': ['min', 'mean', 'max']
})
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Pregunta bonus
#
# #### Para cada departamento, calcule la diferencia entre el salario máximo y el salario mínimo.
#
# ##### * Sugerencia: pruebe a utilizar `agg` o `apply` y `lambda`*.

# %%
# your answer here
employee.groupby('Department')['Salary'].agg(lambda x: x.max() - x.min())
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # Desafío 3

# %% [markdown]
# #### Abra el conjunto de datos Orders.csv. Nombre el conjunto de datos pedidos

# %%
# your answer here
orders = pd.read_csv('./datasets/Orders.csv')

# %% [markdown]
# #### Explore su conjunto de datos observando los tipos de datos y las estadísticas de resumen. Comenta tus resultados

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %% [markdown]
# #### ¿Cuál es el precio medio de compra?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### ¿Cuáles fueron los precios de compra más altos y más bajos?

# %%
# your answer here
orders['UnitPrice'].max()
# Out:
# 8142.75

# %%
# your answer here
orders['UnitPrice'].min()
# Out:
# 0.0

# %% [markdown]
# #### Seleccione todos los clientes que tenemos en España

# %%
orders_spain = orders[orders['Country'] == 'Spain']

# %% [markdown]
# #### ¿Cuántos clientes tenemos en España?
# ##### Pista : Utiliza value_counts()

# %%
# your answer here
orders_spain.value_counts('Country')
# Out:
# Country
# Spain    2485
# Name: count, dtype: int64

# %% [markdown]
# #### Selecciona todos los clientes que han comprado más de 50 artículos ?

# %%
# your answer here
clientes_mas_de_50 = orders.groupby('CustomerID').agg({'Quantity': 'sum'})
clientes_mas_de_50 = clientes_mas_de_50[clientes_mas_de_50['Quantity'] > 50]
clientes_mas_de_50
# Out:
#             Quantity
# CustomerID
# 12346          74215
# 12347           2458
# 12348           2341
# 12349            631
# 12350            197
# ...              ...
# 18278             66
# 18281             54
# 18282            103
# 18283           1397
# 18287           1586
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Selecciona pedidos de España superiores a 50 artículos

# %%
# your answer here
orders[(orders['Country'] == "Spain") & (orders['Quantity'] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Seleccionar todos los pedidos gratuitos

# %%
orders[orders['UnitPrice'] == 0.0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Seleccionar todos los pedidos que sean 'lunch bag
# #### Pista: Utilice las funciones de cadena

# %%
orders[orders['Description'].str.contains("lunch bag")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Seleccione todos los pedidos realizados en 2011 y que sean «lunch bag».

# %%
orders[(orders['year'] == 2011) & (orders['Description'].str.contains("lunch bag"))]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Muestra la distribución de frecuencias del importe gastado en España.

# %%
# your answer here
sns.histplot(orders[(orders['Country'] == "Spain")]['amount_spent'], bins=30)
plt.title("Amount Spent in Spain Histogram")
# Out:
# Text(0.5, 1.0, 'Amount Spent in Spain Histogram')

# %% [markdown]
# #### Seleccione todos los pedidos realizados en el mes de agosto

# %%
# your answer here
orders[orders['month'] == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Seleccione cuántos pedidos se realizan por países en el mes de agosto
# ##### Pista: Utilice value_counts()

# %%
orders[orders['month'] == 8].value_counts('Country')
# Out:
# Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: count, dtype: int64

# %% [markdown]
# #### ¿Cuál es el gasto medio por país?

# %%
orders.groupby('Country')[['amount_spent']].agg('mean')
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### ¿Cuál es el artículo más caro?

# %%
orders.nlargest(1,'UnitPrice') # El más caro es el StockCode POST, con Description "postage"
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### ¿Cuál fue la cantidad media gastada al año?

# %%
orders.groupby('year')[['amount_spent']].agg('mean')
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
